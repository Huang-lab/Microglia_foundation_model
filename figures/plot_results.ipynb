# %%
import pandas as pd
import os.path
import requests
import json

import matplotlib.pyplot as plt
import seaborn as sns

# %%
LOC = "/pasteur/appa/scratch/jkalfon/data/spcrint_data/"

# %%
if not os.path.exists("../data/results_batch.json"):
    url = "https://raw.githubusercontent.com/openproblems-bio/website/main/results/batch_integration/data/results.json"
    response = requests.get(url)

    with open("../data/results_batch.json", "w") as f:
        f.write(response.text)

if not os.path.exists("../data/results_label.json"):
    url = "https://raw.githubusercontent.com/openproblems-bio/website/main/results/label_projection/data/results.json"
    response = requests.get(url)

    with open("../data/results_label.json", "w") as f:
        f.write(response.text)

print("File downloaded successfully!")
# Out:
# File downloaded successfully!

# %%
res = {}
with open("../data/results_batch.json", "r") as f:
    data_batch = json.load(f)
for dataset in data_batch:
    dataset_id = dataset["dataset_id"]
    if dataset_id not in res:
        res[dataset_id] = {}
    res[dataset_id].update({dataset["method_id"]: dataset["metric_values"]})

# %%
res_label = {}
with open("../data/results_label.json", "r") as f:
    data_label = json.load(f)
for dataset in data_label:
    dataset_id = dataset["dataset_id"]
    if dataset_id not in res_label:
        res_label[dataset_id] = {}
    res_label[dataset_id].update({dataset["method_id"]: dataset["metric_values"]})

res_label.keys()
# Out:
# dict_keys(['cellxgene_census/dkd', 'cellxgene_census/gtex_v9', 'cellxgene_census/hypomap', 'cellxgene_census/immune_cell_atlas', 'cellxgene_census/mouse_pancreas_atlas', 'cellxgene_census/tabula_sapiens', None])

# %%
pd.DataFrame(res_label["cellxgene_census/dkd"])
# Out:
#                 knn  logistic_regression  majority_vote     mlp  naive_bayes  \
# accuracy     0.9490               0.9572         0.2954  0.9540       0.9269
# f1_macro     0.9286               0.9413         0.0351  0.9245       0.9181
# f1_micro     0.9490               0.9572         0.2954  0.9540       0.9269
# f1_weighted  0.9487               0.9567         0.1347  0.9529       0.9296
#
#              random_labels  scanvi  scanvi_scarches  scgpt_zeroshot  \
# accuracy            0.1808  0.9570           0.9570          0.8486
# f1_macro            0.0774  0.9360           0.9366          0.5239
# f1_micro            0.1808  0.9570           0.9570          0.8486
# f1_weighted         0.1801  0.9579           0.9567          0.8339
#
#              scimilarity  scimilarity_knn  seurat_transferdata  singler  \
# accuracy          0.8869           0.9553               0.9541   0.9147
# f1_macro          0.6233           0.9292               0.9344   0.9027
# ...

# %%
res.keys()
# Out:
# dict_keys(['cellxgene_census/dkd', 'cellxgene_census/gtex_v9', 'cellxgene_census/hypomap', 'cellxgene_census/immune_cell_atlas', 'cellxgene_census/mouse_pancreas_atlas', 'cellxgene_census/tabula_sapiens'])

# %%
pd.DataFrame(res["cellxgene_census/mouse_pancreas_atlas"]).T
# Out:
#                                      ari asw_batch asw_label  \
# batchelor_fastmnn                  0.565    0.8708    0.6043
# batchelor_mnn_correct                 NA        NA        NA
# bbknn                             0.7124        NA        NA
# combat                             0.565    0.9096     0.552
# embed_cell_types                       1    0.8347    0.9897
# embed_cell_types_jittered              1    0.8404    0.9897
# geneformer                            NA        NA        NA
# harmony                           0.8176    0.8238    0.6033
# harmonypy                         0.8158    0.8291    0.6046
# liger                             0.6645    0.6526     0.519
# mnnpy                                 NA        NA        NA
# no_integration                    0.3403    0.8901     0.604
# no_integration_batch              0.1028    0.7835    0.4776
# pyliger                           0.6615    0.6841    0.5203
# ...

# %%
metrics = {
    "dkd_ref_cls": {
        "accuracy": 0.6050132734327139,
        "macro": 0.45858384601691754,
        "micro": 0.6050132734327139,
        "weighted": 0.5752358078815335,
    },
    "dkd_cls": {
        "accuracy": 0.5608184918529746,
        "macro": 0.49302410982269285,
        "micro": 0.5608184918529746,
        "weighted": 0.5370188034467204,
    },
    "dkd_smooth_cls": {
        "accuracy": 0.5941644562334217,
        "macro": 0.5355514243377841,
        "micro": 0.5941644562334217,
        "weighted": 0.5827613925424003,
    },
    "dkd_clust_cls": {
        "accuracy": 0.5985221674876847,
        "macro": 0.5,
        "micro": 0.5985221674876847,
        "weighted": 0.5985221674876847,
    },
    "gtex_v9_ref_cls": {
        "accuracy": 0.5690731903254497,
        "macro": 0.3561412506114705,
        "micro": 0.5690731903254497,
        "weighted": 0.5111263506144524,
    },
    "gtex_v9_cls": {
        "accuracy": 0.47340980187695514,
        "macro": 0.4771516389245344,
        "micro": 0.47340980187695514,
        "weighted": 0.4105919407683359,
    },
    "gtex_v9_smooth_cls": {
        "accuracy": 0.49930483142161974,
        "macro": 0.45026649672378827,
        "micro": 0.49930483142161974,
        "weighted": 0.46767738060420655,
    },
    "gtex_v9_clust_cls": {
        "accuracy": 0.49930483142161974,
        "macro": 0.45026649672378827,
        "micro": 0.49930483142161974,
        "weighted": 0.46767738060420655,
    },
    "hypomap_ref_cls": {
        "accuracy": 0.9331843865688121,
        "macro": 0.5582565920511067,
        "micro": 0.9331843865688121,
        "weighted": 0.9095025274318423,
    },
    "hypomap_cls": {
        "accuracy": 0.9817518248175182,
        "macro": 0.8017862483599127,
        "micro": 0.9817518248175182,
        "weighted": 0.9743770548339135,
    },
    "hypomap_smooth_cls": {
        "accuracy": 0.9908759124087592,
        "macro": 0.8529747502946833,
        "micro": 0.9908759124087592,
        "weighted": 0.986699566363855,
    },
    "hypomap_clust_cls": {
        "accuracy": 0.9963503649635036,
        "macro": 0.8811979101634128,
        "micro": 0.9963503649635036,
        "weighted": 0.9945824700566079,
    },
    "mouse_pancreas_atlas_ref_cls": {
        "accuracy": 0.9168991697845367,
        "macro": 0.736673219519387,
        "micro": 0.9168991697845367,
        "weighted": 0.8911321328642097,
    },
    "mouse_pancreas_atlas_cls": {
        "accuracy": 0.9222539985171062,
        "macro": 0.7317299769023702,
        "micro": 0.9222539985171062,
        "weighted": 0.8935278968505191,
    },
    "mouse_pancreas_atlas_smooth_cls": {
        "accuracy": 0.9653638385764219,
        "macro": 0.7529330761341159,
        "micro": 0.9653638385764219,
        "weighted": 0.9564964495219883,
    },
    "mouse_pancreas_atlas_clust_cls": {
        "accuracy": 0.9721427814850122,
        "macro": 0.7654463915196114,
        "micro": 0.9721427814850122,
        "weighted": 0.9663853668888627,
    },
}

# %%
metrics_v1 = {
    "dkd_ref_cls": {
        "accuracy": 0.4937716969573208,
        "macro": 0.38015219981782045,
        "micro": 0.4937716969573208,
        "weighted": 0.44125553939089207,
    },
    "dkd_cls": {
        "accuracy": 0.4630541871921182,
        "macro": 0.39612779635380635,
        "micro": 0.4630541871921182,
        "weighted": 0.43238258813181274,
    },
    "gtex_v9_ref_cls": {
        "accuracy": 0.662801373334736,
        "macro": 0.45113362926393386,
        "micro": 0.662801373334736,
        "weighted": 0.6076783134412977,
    },
    "gtex_v9_cls": {
        "accuracy": 0.4894855752519986,
        "macro": 0.5275646372211268,
        "micro": 0.4894855752519986,
        "weighted": 0.45377925621844867,
    },
    "hypomap_ref_cls": {
        "accuracy": 0.8986192115347146,
        "macro": 0.5346630203398964,
        "micro": 0.8986192115347146,
        "weighted": 0.8782631897011843,
    },
    "hypomap_cls": {
        "accuracy": 0.9525547445255474,
        "macro": 0.6734592457544935,
        "micro": 0.9525547445255474,
        "weighted": 0.9472890166071732,
    },
    "mouse_pancreas_atlas_ref_cls": {
        "accuracy": 0.6353696705188564,
        "macro": 0.6829825924446588,
        "micro": 0.6353696705188564,
        "weighted": 0.5402847879953743,
    },
    "mouse_pancreas_atlas_cls": {
        "accuracy": 0.7887935600042368,
        "macro": 0.7095144808117735,
        "micro": 0.7887935600042368,
        "weighted": 0.711819695219025,
    },
}

# %%
metrics_ft = {
    "hypomap_ref_cls": {
        "accuracy": 0.9918841332727155,
        "macro": 0.7696163027141719,
        "micro": 0.9918841332727155,
        "weighted": 0.9880037265383134,
    },
    "hypomap_cls": {
        "accuracy": 0.9972627737226277,
        "macro": 0.8843677466665826,
        "micro": 0.9972627737226277,
        "weighted": 0.9959127236678834,
    },
    "hypomap_smooth_cls": {
        "accuracy": 0.9963503649635036,
        "macro": 0.8811979101634128,
        "micro": 0.9963503649635036,
        "weighted": 0.9945824700566079,
    },
    "hypomap_clust_cls": {
        "accuracy": 0.9936131386861314,
        "macro": 0.7700867990523016,
        "micro": 0.9936131386861314,
        "weighted": 0.9918452437792358,
    },
    "gtex_v9_ref_cls": {
        "accuracy": 0.9615351510572574,
        "macro": 0.8414327209327331,
        "micro": 0.9615351510572574,
        "weighted": 0.9458130470996915,
    },
    "gtex_v9_cls": {
        "accuracy": 0.9396941258255127,
        "macro": 0.8168550944626127,
        "micro": 0.9396941258255127,
        "weighted": 0.9152628809255811,
    },
    "gtex_v9_smooth_cls": {
        "accuracy": 0.9386513729579423,
        "macro": 0.8107972048727167,
        "micro": 0.9386513729579423,
        "weighted": 0.9154172322630404,
    },
    "gtex_v9_clust_cls": {
        "accuracy": 0.9386513729579423,
        "macro": 0.8107972048727167,
        "micro": 0.9386513729579423,
        "weighted": 0.9154172322630404,
    },
    "dkd_ref_cls": {
        "accuracy": 0.957269756994078,
        "macro": 0.8707964783430515,
        "micro": 0.957269756994078,
        "weighted": 0.9380173819914928,
    },
    "dkd_cls": {
        "accuracy": 0.9607805987116332,
        "macro": 0.8670685465118949,
        "micro": 0.9607805987116332,
        "weighted": 0.9429724166641977,
    },
    "dkd_smooth_cls": {
        "accuracy": 0.962485790071997,
        "macro": 0.8773644732834186,
        "micro": 0.962485790071997,
        "weighted": 0.9455708494744246,
    },
    "dkd_clust_cls": {"accuracy": 1.0, "macro": 1.0, "micro": 1.0, "weighted": 1.0},
    "mouse_pancreas_atlas_ref_cls": {
        "accuracy": 0.9866538805682766,
        "macro": 0.9065043136524673,
        "micro": 0.9866538805682766,
        "weighted": 0.9802076562758316,
    },
    "mouse_pancreas_atlas_cls": {
        "accuracy": 0.9843236945238851,
        "macro": 0.8915384242416656,
        "micro": 0.9843236945238851,
        "weighted": 0.9771898577480528,
    },
    "mouse_pancreas_atlas_smooth_cls": {
        "accuracy": 0.9872894820463934,
        "macro": 0.89033441586772,
        "micro": 0.9872894820463934,
        "weighted": 0.9817127498804611,
    },
    "mouse_pancreas_atlas_clust_cls": {
        "accuracy": 0.9819934328990573,
        "macro": 0.8953801102938492,
        "micro": 0.9819934328990573,
        "weighted": 0.9739455319046344,
    },
}

# %%
toplot = {}
names = []
for k, v in res_label.items():
    if k is None:
        continue
    names.append(k.split("/")[1])
    for l, w in v.items():
        if w is None:
            continue
        if l not in toplot:
            toplot[l] = []
        toplot[l].append(w["f1_macro"])
    m = 0
    for l, w in metrics.items():
        if l.startswith(k.split("/")[1]):
            if w["macro"] > m and not l.endswith("ref_cls"):
                m = w["macro"]
    if "scPRINT-2 (zero-shot)" not in toplot:
        toplot["scPRINT-2 (zero-shot)"] = []
    toplot["scPRINT-2 (zero-shot)"].append(m)
    m = 0
    for l, w in metrics_v1.items():
        if l.startswith(k.split("/")[1]):
            if w["macro"] > m and not l.endswith("ref_cls"):
                m = w["macro"]
    if "scPRINT-1 (zero-shot)" not in toplot:
        toplot["scPRINT-1 (zero-shot)"] = []
    toplot["scPRINT-1 (zero-shot)"].append(m)
    m = 0
    for l, w in metrics_ft.items():
        if l.startswith(k.split("/")[1]):
            if w["macro"] > m and not l.endswith("ref_cls"):
                m = w["macro"]
    if "scPRINT-2 (fine-tune)" not in toplot:
        toplot["scPRINT-2 (fine-tune)"] = []
    toplot["scPRINT-2 (fine-tune)"].append(m)
toplot = pd.DataFrame(data=toplot, index=names).T

# %%
toplot = toplot.loc[:, toplot.loc["scPRINT-2 (zero-shot)"].values != 0].drop(
    index=["geneformer", "true_labels", "scgpt_finetuned", "scprint"], errors="ignore"
)

# %%
toplot = toplot.apply(pd.to_numeric, errors="coerce").fillna(0)
toplot
# Out:
#                             dkd   gtex_v9   hypomap  mouse_pancreas_atlas
# knn                    0.928600  0.391300  0.973000              0.842600
# logistic_regression    0.941300  0.443700  0.976700              0.880100
# majority_vote          0.035100  0.008200  0.077800              0.037600
# mlp                    0.924500  0.294800  0.983300              0.838100
# naive_bayes            0.918100  0.336300  0.962600              0.779400
# random_labels          0.077400  0.007100  0.070700              0.071400
# scanvi                 0.936000  0.408300  0.992600              0.875800
# scanvi_scarches        0.936600  0.455500  0.978300              0.905100
# scgpt_zeroshot         0.523900  0.253400  0.000000              0.000000
# scimilarity            0.623300  0.325400  0.000000              0.000000
# scimilarity_knn        0.929200  0.456300  0.000000              0.000000
# seurat_transferdata    0.934400  0.418600  0.989800              0.781900
# ...

# %%
toplot = toplot.loc[
    [
        "knn",
        "logistic_regression",
        "mlp",
        "xgboost",
        "naive_bayes",
        "scanvi",
        "scanvi_scarches",
        "seurat_transferdata",
        "singler",
        "random_labels",
        "majority_vote",
        "uce",
        "scgpt_zeroshot",
        "scimilarity",
        "scimilarity_knn",
        "scPRINT-1 (zero-shot)",
        "scPRINT-2 (zero-shot)",
        "scPRINT-2 (fine-tune)",
    ]
]

# %% [markdown]
# # micro

# %%
FONTSIZE = 30  # taille de base, ajuste selon tes besoins

# Alternative: Boxplot with stripplot overlay
fig, ax = plt.subplots(figsize=(18, 15))

# Melt the dataframe for seaborn
plot_data = toplot.T.reset_index().melt(
    id_vars="index", var_name="Method", value_name="Micro F1 Score"
)
plot_data.columns = ["Dataset", "Method", "Micro F1 Score"]

# Define color palette
colors = ["lightblue"] * len(plot_data["Method"].unique())
scprint_idx = list(plot_data["Method"].unique()).index("scPRINT-2 (zero-shot)")
colors[scprint_idx] = "coral"

# Create boxplot
sns.boxplot(
    data=plot_data,
    x="Method",
    y="Micro F1 Score",
    ax=ax,
    color="lightblue",
    showmeans=True,
    fliersize=0,
    boxprops=dict(alpha=0.6, linewidth=1.5),
    whiskerprops=dict(linewidth=1.5),
    capprops=dict(linewidth=1.5),
    meanprops={
        "marker": "d",
        "markerfacecolor": "black",
        "markeredgecolor": "black",
        "markersize": 10,
    },
)

# Add strip plot to show individual points
sns.stripplot(
    data=plot_data,
    x="Method",
    y="Micro F1 Score",
    hue="Dataset",
    ax=ax,
    alpha=0.6,
    size=8,
    jitter=0.1,
)

# Styling
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=FONTSIZE)
ax.tick_params(axis="y", labelsize=FONTSIZE)
ax.set_ylabel("Micro F1 Score", fontsize=FONTSIZE + 2, fontweight="bold")
ax.set_xlabel("Method", fontsize=FONTSIZE + 2, fontweight="bold")

# Then make the last label bold
labels = ax.get_xticklabels()
labels[-1].set_fontweight("bold")
labels[-2].set_fontweight("bold")

ax.set_title(
    "Label Projection Micro F1 Score Distribution",
    fontsize=FONTSIZE + 4,
    fontweight="bold",
    pad=20,
)
ax.set_ylim([-0.05, 1.05])
ax.legend(loc="lower left", fontsize=FONTSIZE)

plt.tight_layout()
plt.show()

# Print summary statistics
print("\nSummary Statistics:")
print(plot_data.groupby("Method")["Micro F1 Score"].describe().round(3))
# Out:
# /local/scratch/tmp/ipykernel_1785176/3062957501.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=FONTSIZE)
# Summary Statistics:
#                        count   mean    std    min    25%    50%    75%    max
# Method
# knn                      4.0  0.943  0.063  0.852  0.925  0.962  0.981  0.995
# logistic_regression      4.0  0.954  0.050  0.883  0.939  0.968  0.983  0.996
# majority_vote            4.0  0.288  0.154  0.080  0.242  0.310  0.356  0.452
# mlp                      4.0  0.925  0.099  0.778  0.910  0.962  0.977  0.997
# naive_bayes              4.0  0.908  0.103  0.760  0.885  0.939  0.961  0.994
# random_labels            4.0  0.175  0.116  0.032  0.137  0.176  0.215  0.316
# scPRINT-1 (zero-shot)    4.0  0.673  0.238  0.463  0.483  0.639  0.830  0.953
# ...

# %% [markdown]
# # Macro

# %%
FONTSIZE = 30  # taille de base, ajuste selon tes besoins

# Alternative: Boxplot with stripplot overlay
fig, ax = plt.subplots(figsize=(18, 15))

# Melt the dataframe for seaborn
plot_data = toplot.T.reset_index().melt(
    id_vars="index", var_name="Method", value_name="Macro-F1"
)
plot_data.columns = ["Dataset", "Method", "Macro-F1"]

# Define color palette
colors = ["lightblue"] * len(plot_data["Method"].unique())
scprint_idx = list(plot_data["Method"].unique()).index("scPRINT-2 (zero-shot)")
colors[scprint_idx] = "coral"

# Create boxplot
sns.boxplot(
    data=plot_data,
    x="Method",
    y="Macro-F1",
    ax=ax,
    color="lightblue",
    showmeans=True,
    fliersize=0,
    boxprops=dict(alpha=0.6, linewidth=1.5),
    whiskerprops=dict(linewidth=1.5),
    capprops=dict(linewidth=1.5),
    meanprops={
        "marker": "d",
        "markerfacecolor": "black",
        "markeredgecolor": "black",
        "markersize": 10,
    },
)

# Add strip plot to show individual points
sns.stripplot(
    data=plot_data,
    x="Method",
    y="Macro-F1",
    hue="Dataset",
    ax=ax,
    alpha=0.6,
    size=8,
    jitter=0.1,
)

# Styling
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=FONTSIZE)
ax.tick_params(axis="y", labelsize=FONTSIZE)
ax.set_ylabel("Macro-F1", fontsize=FONTSIZE + 2, fontweight="bold")
ax.set_xlabel("Method", fontsize=FONTSIZE + 2, fontweight="bold")

# Then make the last label bold
labels = ax.get_xticklabels()
labels[-1].set_fontweight("bold")
labels[-2].set_fontweight("bold")

ax.set_title(
    "Label Projection Macro-F1 Distribution",
    fontsize=FONTSIZE + 4,
    fontweight="bold",
    pad=20,
)
ax.set_ylim([-0.05, 1.05])
ax.legend(loc="lower left", fontsize=FONTSIZE)

plt.tight_layout()
plt.show()

# Print summary statistics
print("\nSummary Statistics:")
print(plot_data.groupby("Method")["Macro-F1"].describe().round(3))
# Out:
# /local/scratch/tmp/ipykernel_1785176/3359505183.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=FONTSIZE)
# Summary Statistics:
#                        count   mean    std    min    25%    50%    75%    max
# Method
# knn                      4.0  0.784  0.267  0.391  0.730  0.886  0.940  0.973
# logistic_regression      4.0  0.810  0.248  0.444  0.771  0.911  0.950  0.977
# majority_vote            4.0  0.040  0.029  0.008  0.028  0.036  0.048  0.078
# mlp                      4.0  0.760  0.316  0.295  0.702  0.881  0.939  0.983
# naive_bayes              4.0  0.749  0.286  0.336  0.669  0.849  0.929  0.963
# random_labels            4.0  0.057  0.033  0.007  0.055  0.071  0.073  0.077
# scPRINT-1 (zero-shot)    4.0  0.577  0.144  0.396  0.495  0.601  0.682  0.710
# ...

# %% [markdown]
# ### Identical plot, adjusted with larger font size for publication-quality figure:

# %%
FONTSIZE = 30  # taille de base, ajuste selon tes besoins

# Alternative: Boxplot with stripplot overlay
fig, ax = plt.subplots(figsize=(18, 15))

# Melt the dataframe for seaborn
plot_data = toplot.T.reset_index().melt(
    id_vars="index", var_name="Method", value_name="Accuracy"
)
plot_data.columns = ["Dataset", "Method", "Accuracy"]

# Define color palette
colors = ["lightblue"] * len(plot_data["Method"].unique())
scprint_idx = list(plot_data["Method"].unique()).index("scPRINT-2 (zero-shot)")
colors[scprint_idx] = "coral"

# Create boxplot
sns.boxplot(
    data=plot_data,
    x="Method",
    y="Accuracy",
    ax=ax,
    color="lightblue",
    showmeans=True,
    fliersize=0,
    boxprops=dict(alpha=0.6, linewidth=1.5),
    whiskerprops=dict(linewidth=1.5),
    capprops=dict(linewidth=1.5),
    meanprops={
        "marker": "d",
        "markerfacecolor": "black",
        "markeredgecolor": "black",
        "markersize": 10,
    },
)

# Add strip plot to show individual points
sns.stripplot(
    data=plot_data,
    x="Method",
    y="Accuracy",
    hue="Dataset",
    ax=ax,
    alpha=0.6,
    size=8,
    jitter=0.1,
)

# Styling
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=FONTSIZE)
ax.tick_params(axis="y", labelsize=FONTSIZE)
ax.set_ylabel("Accuracy", fontsize=FONTSIZE + 2, fontweight="bold")
ax.set_xlabel("Method", fontsize=FONTSIZE + 2, fontweight="bold")

# Then make the last label bold
labels = ax.get_xticklabels()
labels[-1].set_fontweight("bold")
labels[-2].set_fontweight("bold")

ax.set_title(
    "Label Projection Accuracy Distribution",
    fontsize=FONTSIZE + 4,
    fontweight="bold",
    pad=20,
)
ax.set_ylim([-0.05, 1.05])
ax.legend(loc="lower left", fontsize=FONTSIZE)

plt.tight_layout()
plt.show()

# Print summary statistics
print("\nSummary Statistics:")
print(plot_data.groupby("Method")["Accuracy"].describe().round(3))
# Out:
# /local/scratch/tmp/ipykernel_1785176/3253432953.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=FONTSIZE)
# Summary Statistics:
#                        count   mean    std    min    25%    50%    75%    max
# Method
# knn                      4.0  0.784  0.267  0.391  0.730  0.886  0.940  0.973
# logistic_regression      4.0  0.810  0.248  0.444  0.771  0.911  0.950  0.977
# majority_vote            4.0  0.040  0.029  0.008  0.028  0.036  0.048  0.078
# mlp                      4.0  0.760  0.316  0.295  0.702  0.881  0.939  0.983
# naive_bayes              4.0  0.749  0.286  0.336  0.669  0.849  0.929  0.963
# random_labels            4.0  0.057  0.033  0.007  0.055  0.071  0.073  0.077
# scPRINT-1 (zero-shot)    4.0  0.577  0.144  0.396  0.495  0.601  0.682  0.710
# ...

# %%
emb = pd.DataFrame(
    data={
        "Isolated labels": [
            0.621361,
            0.387139,
            0.520031,
            0.544676,
        ],
        "KMeans NMI": [
            0.655657,
            0.570249,
            0.61668,
            0.516657,
        ],
        "KMeans ARI": [
            0.439839,
            0.225424,
            0.280595,
            0.35364,
        ],
        "Silhouette label": [
            0.562681,
            0.61172,
            0.503856,
            0.547946,
        ],
        "cLISI": [
            0.99952,
            1.0,
            0.996694,
            0.992218,
        ],
        "BRAS": [
            0.739654,
            0.786443,
            0.803204,
            0.761943,
        ],
        "iLISI": [
            0.043682,
            0.0,
            0.077398,
            0.19466,
        ],
        "KBET": [
            0.239296,
            0.844529,
            0.353033,
            0.212243,
        ],
        "Graph connectivity": [
            0.854861,
            0.826488,
            0.704139,
            0.857564,
        ],
        "PCR comparison": [
            0,
            0.41701,
            0.096562,
            0.736278,
        ],
        "Batch correction": [
            0.375498,
            0.574894,
            0.406867,
            0.552538,
        ],
        "Bio conservation": [
            0.655811,
            0.558906,
            0.583571,
            0.591027,
        ],
        "Total": [
            0.543686,
            0.565301,
            0.51289,
            0.575631,
        ],
    },
    index=["mouse_pancreas_atlas", "hypomap", "gtex_v9", "dkd"],
)

# %%
emb_v1 = pd.DataFrame(
    data={
        "Isolated labels": [
            0.566661,
            0.511032,
            0.509863,
            0.657649,
        ],
        "KMeans NMI": [0.645338, 0.238028, 0.567372, 0.426683],
        "KMeans ARI": [0.31973, 0.11652, 0.391042, 0.134236],
        "Silhouette label": [0.508098, 0.514257, 0.54277, 0.558273],
        "cLISI": [0.997801, 0.956136, 0.999368, 1.0],
        "BRAS": [0.816372, 0.74002, 0.682742, 0.778155],
        "iLISI": [0.052263, 0.150554, 0.03697, 0.0],
        "KBET": [0.314974, 0.169856, 0.193596, 0.849659],
        "Graph connectivity": [0.764403, 0.768737, 0.872287, 0.825514],
        "PCR comparison": [
            0,
            0.269315,
            0,
            0,
        ],
        "Batch correction": [0.389602, 0.419696, 0.357119, 0.490666],
        "Bio conservation": [0.607526, 0.467195, 0.63164, 0.525811],
        "Total": [0.520356, 0.448195, 0.521832, 0.511753],
    },
    index=[
        "gtex_v9",
        "dkd",
        "hypomap",
        "mouse_pancreas_atlas",
    ],
)

# %%
emb_ft = pd.DataFrame(
    data={
        "Isolated labels": [0.709752, 0.582134, 0.174419, 0.78184],
        "KMeans NMI": [0.792065, 0.804217, 0.747984, 0.799543],
        "KMeans ARI": [0.664956, 0.523745, 0.438869, 0.633139],
        "Silhouette label": [0.735049, 0.670654, 0.856273, 0.756145],
        "cLISI": [
            1.0,
            0.999889,
            1.0,
            1.0,
        ],
        "BRAS": [0.740067, 0.699155, 0.575672, 0.721834],
        "iLISI": [1.0, 0.037238, 0.0, 0.041376],
        "KBET": [0.264008, 0.335034, 0.83096, 0.274245],
        "Graph connectivity": [0.92774, 0.886459, 0.887689, 0.953396],
        "PCR comparison": [0.798539, 0, 0.533793, 0.177941],
        "Batch correction": [0.58494, 0.391577, 0.565623, 0.433758],
        "Bio conservation": [0.780365, 0.716128, 0.643509, 0.794133],
        "Total": [0.702195, 0.586308, 0.612354, 0.649983],
    },
    index=["dkd", "gtex_v9", "hypomap", "mouse_pancreas_atlas"],
)

# %%
res.keys()
# Out:
# dict_keys(['cellxgene_census/dkd', 'cellxgene_census/gtex_v9', 'cellxgene_census/hypomap', 'cellxgene_census/immune_cell_atlas', 'cellxgene_census/mouse_pancreas_atlas', 'cellxgene_census/tabula_sapiens'])

# %%
toplot = {}
names = []
for k, v in res.items():
    if k is None:
        continue
    names.append(k)
    for l, w in v.items():
        cell = 0

        for c in [
            "ari",
            "nmi",
            "isolated_label_asw",
            "clisi",
            "asw_label",
        ]:
            if w[c] == "NA":
                continue
            cell += w[c]
        cell /= 5
        batch = 0

        for b in [
            "pcr",
            "graph_connectivity",
            "asw_batch",
            "ilisi",
            "kbet",
        ]:
            if w[b] == "NA":
                continue
            batch += w[b]
        batch /= 5
        total = cell * 0.4 + batch * 0.6
        if l not in toplot:
            toplot[l] = []
        toplot[l].append(batch)
    # print(f"         Bio: {cell:.3f}")
    # print(f"         Batch: {batch:.3f}")
    if "scPRINT-2 (zero-shot)" not in toplot:
        toplot["scPRINT-2 (zero-shot)"] = []
    if k.split("/")[1] not in emb.index:
        toplot["scPRINT-2 (zero-shot)"].append(0)
    else:
        toplot["scPRINT-2 (zero-shot)"].append(emb.loc[k.split("/")[1], "Batch correction"])
    if "scPRINT-1 (zero-shot)" not in toplot:
        toplot["scPRINT-1 (zero-shot)"] = []
    if k.split("/")[1] not in emb_v1.index:
        toplot["scPRINT-1 (zero-shot)"].append(0)
    else:
        toplot["scPRINT-1 (zero-shot)"].append(emb_v1.loc[k.split("/")[1], "Batch correction"])
    if "scPRINT-2 (fine-tune)" not in toplot:
        toplot["scPRINT-2 (fine-tune)"] = []
    if k.split("/")[1] not in emb_ft.index:
        toplot["scPRINT-2 (fine-tune)"].append(0)
    else:
        toplot["scPRINT-2 (fine-tune)"].append(emb_ft.loc[k.split("/")[1], "Batch correction"])
toplot = pd.DataFrame(data=toplot, index=names).T

# %%
toplot = toplot.loc[:, toplot.loc["scPRINT-2 (zero-shot)"].values != 0].drop(
    index=["geneformer", "true_labels", "scgpt_finetuned", "scprint"], errors="ignore"
)
toplot
# Out:
#                                   cellxgene_census/dkd  \
# batchelor_fastmnn                             0.611000
# batchelor_mnn_correct                         0.568100
# bbknn                                         0.267320
# combat                                        0.643600
# embed_cell_types                              0.786580
# embed_cell_types_jittered                     0.784140
# harmony                                       0.664440
# harmonypy                                     0.664360
# liger                                         0.765240
# mnnpy                                         0.450600
# no_integration                                0.417940
# no_integration_batch                          0.466740
# pyliger                                       0.767760
# scalex                                        0.683280
# scanorama                                     0.455000
# scanvi                                        0.620240
# ...

# %%
toplot.columns = toplot.columns.str.split("/").str[1]
toplot = toplot.loc[
    [
        "no_integration_batch",
        "no_integration",
        "shuffle_integration",
        "shuffle_integration_by_batch",
        "shuffle_integration_by_cell_type",
        "embed_cell_types",
        "embed_cell_types_jittered",
        "batchelor_mnn_correct",
        "mnnpy",
        "bbknn",
        "scanorama",
        "batchelor_fastmnn",
        "harmony",
        "combat",
        "harmonypy",
        "scalex",
        "scanvi",
        "pyliger",
        "liger",
        "scvi",
        "uce",
        "scgpt_zeroshot",
        "scimilarity",
        "scPRINT-1 (zero-shot)",
        "scPRINT-2 (zero-shot)",
        "scPRINT-2 (fine-tune)",
    ]
]

# %% [markdown]
# # total

# %%
FONTSIZE = 15

# Alternative: Boxplot with stripplot overlay
fig, ax = plt.subplots(figsize=(14, 8))

# Melt the dataframe for seaborn
plot_data = toplot.T.reset_index().melt(
    id_vars="index", var_name="Method", value_name="Total Score"
)
plot_data.columns = ["Dataset", "Method", "Total Score"]

# Define color palette
colors = ["lightblue"] * len(plot_data["Method"].unique())
scprint_idx = list(plot_data["Method"].unique()).index("scPRINT-2 (zero-shot)")
colors[scprint_idx] = "coral"

# Create boxplot
sns.boxplot(
    data=plot_data,
    x="Method",
    y="Total Score",
    ax=ax,
    color="lightblue",
    showmeans=True,
    fliersize=0,
    boxprops=dict(alpha=0.6, linewidth=1.5),
    whiskerprops=dict(linewidth=1.5),
    capprops=dict(linewidth=1.5),
    meanprops={"marker": "d", "markerfacecolor": "black", "markeredgecolor": "black"},
)

# Add strip plot to show individual points
sns.stripplot(
    data=plot_data,
    x="Method",
    y="Total Score",
    hue="Dataset",
    ax=ax,
    alpha=0.6,
    size=6,
    jitter=0.2,
)

# Styling
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=FONTSIZE)
ax.tick_params(axis="y", labelsize=FONTSIZE)
ax.set_ylabel("scIB Total score", fontsize=FONTSIZE + 2, fontweight="bold")
ax.set_xlabel("Method", fontsize=FONTSIZE + 2, fontweight="bold")

# Then make the last label bold
labels = ax.get_xticklabels()
labels[-1].set_fontweight("bold")
labels[-2].set_fontweight("bold")

ax.set_title(
    "scIB Total Score Distribution",
    fontsize=FONTSIZE + 4,
    fontweight="bold",
    pad=20,
)
ax.set_ylim([-0.01, 0.8])
ax.legend(loc="lower center", fontsize=FONTSIZE - 2)
ax.axvline(16.5, color=".4", dashes=(1, 1))
ax.axvline(6.5, color=".4", dashes=(1, 1))
ax.axhline(0.634, color=".4", dashes=(1, 1))
ax.axhline(0.51, color=".4", dashes=(1, 1))
plt.show()

# Print summary statistics
print("\nSummary Statistics:")
print(plot_data.groupby("Method")["Total Score"].describe().round(3))
# Out:
# /local/scratch/tmp/ipykernel_1785176/1749179590.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=FONTSIZE)
# Summary Statistics:
#                                   count   mean    std    min    25%    50%  \
# Method
# batchelor_fastmnn                   4.0  0.551  0.062  0.477  0.523  0.550
# batchelor_mnn_correct               4.0  0.150  0.300  0.000  0.000  0.000
# bbknn                               4.0  0.342  0.015  0.330  0.334  0.336
# combat                              4.0  0.618  0.043  0.554  0.612  0.637
# embed_cell_types                    4.0  0.746  0.046  0.682  0.732  0.756
# embed_cell_types_jittered           4.0  0.746  0.045  0.682  0.732  0.755
# harmony                             4.0  0.598  0.058  0.521  0.574  0.605
# ...

# %% [markdown]
# # BIO

# %%
FONTSIZE = 15

# Alternative: Boxplot with stripplot overlay
fig, ax = plt.subplots(figsize=(14, 8))

# Melt the dataframe for seaborn
plot_data = toplot.T.reset_index().melt(
    id_vars="index", var_name="Method", value_name="Bio Score"
)
plot_data.columns = ["Dataset", "Method", "Bio Score"]

# Define color palette
colors = ["lightblue"] * len(plot_data["Method"].unique())
scprint_idx = list(plot_data["Method"].unique()).index("scPRINT-2 (zero-shot)")
colors[scprint_idx] = "coral"

# Create boxplot
sns.boxplot(
    data=plot_data,
    x="Method",
    y="Bio Score",
    ax=ax,
    color="lightblue",
    showmeans=True,
    fliersize=0,
    boxprops=dict(alpha=0.6, linewidth=1.5),
    whiskerprops=dict(linewidth=1.5),
    capprops=dict(linewidth=1.5),
    meanprops={"marker": "d", "markerfacecolor": "black", "markeredgecolor": "black"},
)

# Add strip plot to show individual points
sns.stripplot(
    data=plot_data,
    x="Method",
    y="Bio Score",
    hue="Dataset",
    ax=ax,
    alpha=0.6,
    size=6,
    jitter=0.2,
)

# Styling
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=FONTSIZE)
ax.tick_params(axis="y", labelsize=FONTSIZE)
ax.set_ylabel("scIB Bio score", fontsize=FONTSIZE + 2, fontweight="bold")
ax.set_xlabel("Method", fontsize=FONTSIZE + 2, fontweight="bold")

# Then make the last label bold
labels = ax.get_xticklabels()
labels[-1].set_fontweight("bold")
labels[-2].set_fontweight("bold")

ax.set_title(
    "scIB Bio Score Distribution",
    fontsize=FONTSIZE + 4,
    fontweight="bold",
    pad=20,
)
ax.set_ylim([-0.01, 1.01])
ax.legend(loc="lower center", fontsize=FONTSIZE - 2)
ax.axvline(16.5, color=".4", dashes=(1, 1))
ax.axvline(6.5, color=".4", dashes=(1, 1))
ax.axhline(0.64, color=".4", dashes=(1, 1))
plt.show()

# Print summary statistics
print("\nSummary Statistics:")
print(plot_data.groupby("Method")["Bio Score"].describe().round(3))
# Out:
# /local/scratch/tmp/ipykernel_1785176/3987506150.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=FONTSIZE)
# Summary Statistics:
#                                   count   mean    std    min    25%    50%  \
# Method
# batchelor_fastmnn                   4.0  0.668  0.071  0.581  0.633  0.672
# batchelor_mnn_correct               4.0  0.162  0.325  0.000  0.000  0.000
# bbknn                               4.0  0.493  0.026  0.470  0.471  0.491
# combat                              4.0  0.651  0.073  0.551  0.619  0.671
# embed_cell_types                    4.0  0.945  0.098  0.798  0.943  0.994
# embed_cell_types_jittered           4.0  0.945  0.098  0.798  0.943  0.994
# harmony                             4.0  0.687  0.072  0.620  0.645  0.669
# ...

# %% [markdown]
# # Batch

# %%
FONTSIZE = 15

# Alternative: Boxplot with stripplot overlay
fig, ax = plt.subplots(figsize=(14, 8))

# Melt the dataframe for seaborn
plot_data = toplot.T.reset_index().melt(
    id_vars="index", var_name="Method", value_name="Batch Score"
)
plot_data.columns = ["Dataset", "Method", "Batch Score"]

# Define color palette
colors = ["lightblue"] * len(plot_data["Method"].unique())
scprint_idx = list(plot_data["Method"].unique()).index("scPRINT-2 (zero-shot)")
colors[scprint_idx] = "coral"

# Create boxplot
sns.boxplot(
    data=plot_data,
    x="Method",
    y="Batch Score",
    ax=ax,
    color="lightblue",
    showmeans=True,
    fliersize=0,
    boxprops=dict(alpha=0.6, linewidth=1.5),
    whiskerprops=dict(linewidth=1.5),
    capprops=dict(linewidth=1.5),
    meanprops={"marker": "d", "markerfacecolor": "black", "markeredgecolor": "black"},
)

# Add strip plot to show individual points
sns.stripplot(
    data=plot_data,
    x="Method",
    y="Batch Score",
    hue="Dataset",
    ax=ax,
    alpha=0.6,
    size=6,
    jitter=0.2,
)

# Styling
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=FONTSIZE)
ax.tick_params(axis="y", labelsize=FONTSIZE)
ax.set_ylabel("scIB Batch score", fontsize=FONTSIZE + 2, fontweight="bold")
ax.set_xlabel("Method", fontsize=FONTSIZE + 2, fontweight="bold")

# Then make the last label bold
labels = ax.get_xticklabels()
labels[-1].set_fontweight("bold")
labels[-2].set_fontweight("bold")

ax.set_title(
    "scIB Batch Score Distribution",
    fontsize=FONTSIZE + 4,
    fontweight="bold",
    pad=20,
)
ax.set_ylim([-0.01, .851])
ax.legend(loc="lower center", fontsize=FONTSIZE - 2)
ax.axvline(16.5, color=".4", dashes=(1, 1))
ax.axvline(6.5, color=".4", dashes=(1, 1))
ax.axhline(0.633, color=".4", dashes=(1, 1))
ax.axhline(0.422, color=".4", dashes=(1, 1))
plt.show()

# Print summary statistics
print("\nSummary Statistics:")
print(plot_data.groupby("Method")["Batch Score"].describe().round(3))
# Out:
# /local/scratch/tmp/ipykernel_1785176/2095990796.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", fontsize=FONTSIZE)
# Summary Statistics:
#                                   count   mean    std    min    25%    50%  \
# Method
# batchelor_fastmnn                   4.0  0.473  0.093  0.408  0.429  0.436
# batchelor_mnn_correct               4.0  0.142  0.284  0.000  0.000  0.000
# bbknn                               4.0  0.241  0.022  0.215  0.231  0.240
# combat                              4.0  0.596  0.038  0.556  0.572  0.591
# embed_cell_types                    4.0  0.613  0.130  0.472  0.556  0.597
# embed_cell_types_jittered           4.0  0.613  0.129  0.474  0.556  0.596
# harmony                             4.0  0.538  0.100  0.454  0.460  0.517
# ...

# %%
# Alternative: Boxplot with stripplot overlay
fig, ax = plt.subplots(figsize=(14, 8))

# Melt the dataframe for seaborn
plot_data = toplot.T.reset_index().melt(
    id_vars="index", var_name="Method", value_name="Accuracy"
)
plot_data.columns = ["Dataset", "Method", "Accuracy"]

# Define color palette
colors = ["lightblue"] * len(plot_data["Method"].unique())
scprint_idx = list(plot_data["Method"].unique()).index("scPRINT-2 (zero-shot)")
colors[scprint_idx] = "coral"

# Create boxplot
sns.boxplot(
    data=plot_data,
    x="Method",
    y="Accuracy",
    ax=ax,
    color="lightblue",
    # palette=colors,
    # hue='Dataset',
    showmeans=True,
    fliersize=0,
    # medianprops=dict(color="black", linewidth=2.5),
    boxprops=dict(alpha=0.6, linewidth=1.5),
    whiskerprops=dict(linewidth=1.5),
    capprops=dict(linewidth=1.5),
    meanprops={"marker": "d", "markerfacecolor": "black", "markeredgecolor": "black"},
    # flierprops=dict(marker="o", markerfacecolor="gray", markersize=5, alpha=0.5),
)

# Add strip plot to show individual points
sns.stripplot(
    data=plot_data,
    x="Method",
    y="Accuracy",
    hue="Dataset",
    ax=ax,
    # color="black",
    alpha=0.6,
    size=6,
    jitter=0.2,
)

# Styling
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
ax.set_ylabel("scIB score", fontsize=13, fontweight="bold")
ax.set_xlabel("Method", fontsize=13, fontweight="bold")
# Then make the last label bold
labels = ax.get_xticklabels()
labels[-1].set_fontweight("bold")
labels[-2].set_fontweight("bold")
ax.set_title(
    "scIB Batch Correction Distribution", fontsize=15, fontweight="bold", pad=20
)
ax.set_ylim([-0.05, 1.05])
# ax.axhline(y=0.5, color="gray", linestyle="--", alpha=0.4, linewidth=1.5, zorder=0)
ax.legend(loc="lower right", fontsize=10)
ax.axvline(17.5, color=".3", dashes=(2, 2))
ax.axhline(0.745, color=".4", dashes=(1, 1))
ax.axhline(0.425, color=".4", dashes=(1, 1))
# plt.tight_layout()
plt.show()

# Print summary statistics
print("\nSummary Statistics:")
print(plot_data.groupby("Method")["Accuracy"].describe().round(3))
# Out:
# /local/scratch/tmp/ipykernel_1066606/3659466378.py:48: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
# Summary Statistics:
#                                   count   mean    std    min    25%    50%  \
# Method
# batchelor_fastmnn                   4.0  0.551  0.062  0.477  0.523  0.550
# batchelor_mnn_correct               4.0  0.150  0.300  0.000  0.000  0.000
# bbknn                               4.0  0.342  0.015  0.330  0.334  0.336
# combat                              4.0  0.618  0.043  0.554  0.612  0.637
# embed_cell_types                    4.0  0.746  0.046  0.682  0.732  0.756
# embed_cell_types_jittered           4.0  0.746  0.045  0.682  0.732  0.755
# harmony                             4.0  0.598  0.058  0.521  0.574  0.605
# harmonypy                           4.0  0.597  0.057  0.522  0.572  0.603
# ...
